# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/00_intro_python/06_square_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
    number = float(input("Type a number to see its square: "))
    square = number * number
    print(f"{number} squared is {square}")
if __name__ == '__main__':
    main()
# Out:
# Type a number to see its square: 4
# 4.0 squared is 16.0
