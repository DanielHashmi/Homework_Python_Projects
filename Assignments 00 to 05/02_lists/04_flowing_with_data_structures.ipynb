# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/02_lists/04_flowing_with_data_structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_three_copies(l, copy):
    for _ in range(3):
        l.append(copy)
    print("Inside Func:",l)

l = []
add_three_copies(l,'Hello, World')
print("Outside Func:",l)
# Out:
# Inside Func: ['Hello, World', 'Hello, World', 'Hello, World']
# Outside Func: ['Hello, World', 'Hello, World', 'Hello, World']
