# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/01_expressions/07_tiny_mad_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SENTENCE_START: str = "Panaversity is fun. I learned to program and used Python to make my "

def main():
    adjective: str = input("Please type an adjective and press enter. ")
    noun: str = input("Please type a noun and press enter. ")
    verb: str = input("Please type a verb and press enter. ")

    print(SENTENCE_START + adjective + " " + noun + " " + verb + "!")
if __name__ == '__main__':
    main()
# Out:
# Please type an adjective and press enter. song
# Please type a noun and press enter. justin bieber
# Please type a verb and press enter. singing
# Panaversity is fun. I learned to program and used Python to make my song justin bieber singing!
