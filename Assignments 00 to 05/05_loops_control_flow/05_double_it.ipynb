# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/05_loops_control_flow/05_double_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number: "))
curr_value = number
final_value = 100

while curr_value < final_value:
    curr_value *= 2
    print(curr_value)
# Out:
# Enter a number: 2
# 4
# 8
# 16
# 32
# 64
# 128
