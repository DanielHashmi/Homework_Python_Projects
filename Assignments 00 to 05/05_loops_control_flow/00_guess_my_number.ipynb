# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/05_loops_control_flow/00_guess_my_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def main():
    secret_number = random.randint(1, 99)

    print("I am thinking of a number between 1 and 99...")
    guess = int(input("Enter a guess: "))
    while guess != secret_number:
        if guess < secret_number:
            print("Your guess is too low")
        else:
            print("Your guess is too high")

        print()
        guess = int(input("Enter a new guess: "))
    print(f"Congrats! The number was: {str(secret_number)}")

if __name__ == '__main__':
    main()
# Out:
# I am thinking of a number between 1 and 99...
# Enter a guess: 5
# Your guess is too low
#
# Enter a new guess: 19
# Your guess is too low
#
# Enter a new guess: 49
# Your guess is too low
#
# Enter a new guess: 70
# Your guess is too low
#
# Enter a new guess: 80
# Your guess is too low
#
# Enter a new guess: 90
# Your guess is too high
#
# Enter a new guess: 95
# Your guess is too high
#
# Enter a new guess: 94
# Your guess is too high
#
# Enter a new guess: 92
# Your guess is too high
#
# Enter a new guess: 01
# Your guess is too low
#
# Enter a new guess: 91
# Your guess is too high
#
# Enter a new guess: 90
# Your guess is too high
#
# Enter a new guess: 85
# Your guess is too high
#
# Enter a new guess: 83
# Your guess is too low
#
# Enter a new guess: 84
# Congrats! The number was: 84
