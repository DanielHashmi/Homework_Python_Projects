# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/25%20Projects/Rock%2C_Paper%2C_Scissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def get_player_choice():
  while True:
    choice = input("Enter your choice (r for Rock) (p for Paper) (s for Scissors): ").lower()
    if choice in ["r", "p", "s"]:
      return choice
    else:
      print("Invalid choice. Please try again.")

def get_computer_choice():
  choices = ["r", "p", "s"]
  return random.choice(choices)

def check_winner(player_choice, computer_choice):
    choices = {
        'r':'Rock',
        'p':'Paper',
        's':'Scissors'
    }
    print(f"Your choice is {choices[player_choice]}, computer choice is {choices[computer_choice]}.")

    if player_choice == computer_choice:
        return "It's a tie!"
    elif (player_choice == "r" and computer_choice == "s") or \
        (player_choice == "p" and computer_choice == "r") or \
        (player_choice == "s" and computer_choice == "p"):
        return "You win!"
    else:
        return "Computer wins!"

def play_game():
  player_choice = get_player_choice()
  computer_choice = get_computer_choice()
  result = check_winner(player_choice, computer_choice)
  print(result)

def main():
    play_game()

if __name__ == "__main__":
    main()
# Out:
# Enter your choice (r for Rock) (p for Paper) (s for Scissors): r
# Your choice is Rock, computer choice is Paper.
# Computer wins!
