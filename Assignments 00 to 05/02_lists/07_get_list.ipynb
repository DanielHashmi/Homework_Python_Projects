# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/02_lists/07_get_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = []
user = input("Enter a value: ")
while user:
    lst.append(user)
    user = input("Enter a value: ")

print("Here is the list:", lst)
# Out:
# Enter a value: 1
# Enter a value: 2
# Enter a value: 3
# Enter a value:
# Here is the list: ['1', '2', '3']
