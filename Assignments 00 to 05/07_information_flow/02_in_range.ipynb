# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHashmi/Homework_Python_Projects/blob/main/Assignments%2000%20to%2005/07_information_flow/02_in_range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def in_range(n, low, high):
    if n >= low and n <= high:
	    return True
    return False

print(in_range(14, 10, 20))
# Out:
# True
